# %%
#1Write a Python program to print "Hello Python"?
print("Hello Python")
# Out:
# Hello Python

# %%
#2Write a Python program to do arithmetical operations addition and division?
a = 10
b = 5
addition = a + b
print(addition)
division = a/b
print(division)
# Out:
# 15
# 2.0

# %%
#3Write a Python program to find the area of a triangle?
base = 10
height = 5
area = (base * height) / 2
print(area)
# Out:
# 25.0

# %%
#Write a Python program to swap two variables?
a = 10
b = 20
print(a, b)
a,b = b,a
print(a, b)
# Out:
# 10 20
# 20 10

# %%
#Write a Python program to generate a random number?
import random
a = random.randint(1, 100)
print(a)
#prints any random integer between two given values
# Out:
# 20
